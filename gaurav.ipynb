# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib. dates as mandates

# %%
#Get the Dataset
df = pd.read_csv('https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv')

# %%
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
df.shape
# Out:
# (2035, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
df.isna().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
df.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
numeric_columns = df.select_dtypes(include=np.number).columns
df_numeric = df[numeric_columns].apply(pd.to_numeric, errors='coerce')
fig, ax = plt.subplots(figsize=(8, 10))
sns.heatmap(df_numeric.corr(), vmin=-1, vmax=1, annot=True, ax=ax)
plt.show()

# %%
df.hist(figsize=(10,10),grid=False)
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>,
#         <Axes: title={'center': 'Low'}>],
#        [<Axes: title={'center': 'Last'}>,
#         <Axes: title={'center': 'Close'}>,
#         <Axes: title={'center': 'Total Trade Quantity'}>],
#        [<Axes: title={'center': 'Turnover (Lacs)'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.figure(figsize=(8,5))
df['Open'].plot(kind='line',figsize=(10,5),label="Opening Price")
plt.ylabel("Price")
plt.legend()
plt.title("Change in opening price over the years")
plt.grid()

# %%
plt.figure(figsize=(8,5))
df['Close'].plot(kind='line',figsize=(10,5),color='turquoise',label="Closing Price")
plt.ylabel("Price")
plt.legend()
plt.title("Change in Closing price over the years")
plt.grid()

# %%
high_df =df.reset_index()['High']
plt.plot(high_df)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range = (0,1))
high_df = scaler.fit_transform(np.array(high_df).reshape(-1,1))

# %%
high_df
# Out:
# array([[0.62268754],
#        [0.62614353],
#        [0.6391543 ],
#        ...,
#        [0.15917869],
#        [0.15938199],
#        [0.16344786]])

# %%
high_df.shape
# Out:
# (2035, 1)

# %%
training_size = int(len(high_df) * 0.75)
test_size = len(high_df) - training_size
train_data,test_data = high_df[0:training_size,:], high_df[training_size:len(high_df),:1]

# %%
training_size, test_size
# Out:
# (1526, 509)

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]  
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
x_train, y_train = create_dataset(train_data, time_step)
x_test, y_test = create_dataset(test_data, time_step)

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1425, 100, 1)
# (1425,)
# (408, 100, 1)
# (408,)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
from keras. utils.vis_utils import plot_model

# %%
model = Sequential()
model.add(LSTM(50, return_sequences = True, input_shape = (100,1)))
model.add(LSTM(50, return_sequences = True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 100, batch_size = 64, verbose = 1)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 8s 182ms/step - loss: 0.0281 - val_loss: 0.0086
# Epoch 2/100
# 23/23 [==============================] - 3s 145ms/step - loss: 0.0027 - val_loss: 7.9540e-04
# Epoch 3/100
# 23/23 [==============================] - 3s 141ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 4/100
# 23/23 [==============================] - 3s 137ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 5/100
# 23/23 [==============================] - 3s 153ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 6/100
# 23/23 [==============================] - 3s 152ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 7/100
# 23/23 [==============================] - 3s 139ms/step - loss: 0.0015 - val_loss: 9.3975e-04
# Epoch 8/100
# 23/23 [==============================] - 3s 151ms/step - loss: 0.0016 - val_loss: 8.7739e-04
# Epoch 9/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0012 - val_loss: 7.6589e-04
# Epoch 10/100
# 23/23 [==============================] - 5s 202ms/step - loss: 0.0013 - val_loss: 9.8198e-04
# Epoch 11/100
# 23/23 [==============================] - 5s 243ms/step - loss: 0.0011 - val_loss: 9.8693e-04
# Epoch 12/100
# 23/23 [==============================] - 8s 349ms/step - loss: 0.0011 - val_loss: 7.1506e-04
# Epoch 13/100
# 23/23 [==============================] - 9s 389ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 14/100
# 23/23 [==============================] - 8s 358ms/step - loss: 9.7182e-04 - val_loss: 8.6806e-04
# Epoch 15/100
# 23/23 [==============================] - 8s 364ms/step - loss: 8.8053e-04 - val_loss: 8.2513e-04
# Epoch 16/100
# 23/23 [==============================] - 7s 314ms/step - loss: 8.9164e-04 - val_loss: 9.8659e-04
# Epoch 17/100
# 23/23 [==============================] - 8s 368ms/step - loss: 9.6817e-04 - val_loss: 7.2423e-04
# Epoch 18/100
# 23/23 [==============================] - 9s 384ms/step - loss: 9.2277e-04 - val_loss: 8.5628e-04
# Epoch 19/100
# 23/23 [==============================] - 8s 341ms/step - loss: 7.9263e-04 - val_loss: 6.9459e-04
# Epoch 20/100
# 23/23 [==============================] - 10s 440ms/step - loss: 8.9785e-04 - val_loss: 8.0773e-04
# Epoch 21/100
# 23/23 [==============================] - 10s 434ms/step - loss: 7.6394e-04 - val_loss: 8.3067e-04
# Epoch 22/100
# 23/23 [==============================] - 9s 394ms/step - loss: 7.8379e-04 - val_loss: 7.8579e-04
# Epoch 23/100
# 23/23 [==============================] - 4s 165ms/step - loss: 8.2971e-04 - val_loss: 8.0638e-04
# Epoch 24/100
# 23/23 [==============================] - 4s 168ms/step - loss: 8.4458e-04 - val_loss: 8.0008e-04
# Epoch 25/100
# 23/23 [==============================] - 4s 159ms/step - loss: 6.6826e-04 - val_loss: 6.5148e-04
# Epoch 26/100
# 23/23 [==============================] - 4s 156ms/step - loss: 6.5224e-04 - val_loss: 6.7940e-04
# Epoch 27/100
# 23/23 [==============================] - 4s 154ms/step - loss: 6.9643e-04 - val_loss: 7.5444e-04
# Epoch 28/100
# 23/23 [==============================] - 4s 161ms/step - loss: 6.4093e-04 - val_loss: 7.2181e-04
# Epoch 29/100
# 23/23 [==============================] - 3s 148ms/step - loss: 6.2210e-04 - val_loss: 8.8012e-04
# Epoch 30/100
# 23/23 [==============================] - 4s 158ms/step - loss: 6.2140e-04 - val_loss: 8.9088e-04
# Epoch 31/100
# 23/23 [==============================] - 5s 207ms/step - loss: 5.6960e-04 - val_loss: 7.1699e-04
# Epoch 32/100
# 23/23 [==============================] - 5s 198ms/step - loss: 6.1785e-04 - val_loss: 8.8517e-04
# Epoch 33/100
# 23/23 [==============================] - 5s 216ms/step - loss: 6.3643e-04 - val_loss: 6.6445e-04
# Epoch 34/100
# 23/23 [==============================] - 4s 175ms/step - loss: 6.5940e-04 - val_loss: 6.1657e-04
# Epoch 35/100
# 23/23 [==============================] - 4s 169ms/step - loss: 5.5868e-04 - val_loss: 5.3132e-04
# Epoch 36/100
# 23/23 [==============================] - 5s 220ms/step - loss: 5.4528e-04 - val_loss: 6.3309e-04
# Epoch 37/100
# 23/23 [==============================] - 4s 171ms/step - loss: 5.9248e-04 - val_loss: 7.4118e-04
# Epoch 38/100
# 23/23 [==============================] - 5s 201ms/step - loss: 5.5226e-04 - val_loss: 9.1123e-04
# Epoch 39/100
# 23/23 [==============================] - 4s 184ms/step - loss: 5.2013e-04 - val_loss: 5.1580e-04
# Epoch 40/100
# 23/23 [==============================] - 4s 178ms/step - loss: 6.0505e-04 - val_loss: 5.6847e-04
# Epoch 41/100
# 23/23 [==============================] - 5s 198ms/step - loss: 5.1452e-04 - val_loss: 7.0176e-04
# Epoch 42/100
# 23/23 [==============================] - 4s 183ms/step - loss: 5.1360e-04 - val_loss: 7.4907e-04
# Epoch 43/100
# 23/23 [==============================] - 4s 167ms/step - loss: 5.1694e-04 - val_loss: 6.5831e-04
# Epoch 44/100
# 23/23 [==============================] - 4s 181ms/step - loss: 4.8667e-04 - val_loss: 6.1979e-04
# Epoch 45/100
# 23/23 [==============================] - 4s 190ms/step - loss: 4.7316e-04 - val_loss: 6.3352e-04
# Epoch 46/100
# 23/23 [==============================] - 4s 174ms/step - loss: 4.5048e-04 - val_loss: 6.4361e-04
# Epoch 47/100
# 23/23 [==============================] - 5s 228ms/step - loss: 4.6033e-04 - val_loss: 4.6172e-04
# Epoch 48/100
# 23/23 [==============================] - 8s 357ms/step - loss: 4.4213e-04 - val_loss: 4.6080e-04
# Epoch 49/100
# 23/23 [==============================] - 9s 388ms/step - loss: 4.5300e-04 - val_loss: 4.1566e-04
# Epoch 50/100
# 23/23 [==============================] - 11s 479ms/step - loss: 4.8932e-04 - val_loss: 3.8284e-04
# Epoch 51/100
# 23/23 [==============================] - 9s 383ms/step - loss: 5.8137e-04 - val_loss: 3.3296e-04
# Epoch 52/100
# 23/23 [==============================] - 3s 152ms/step - loss: 4.3943e-04 - val_loss: 4.6699e-04
# Epoch 53/100
# 23/23 [==============================] - 3s 150ms/step - loss: 4.0508e-04 - val_loss: 4.0355e-04
# Epoch 54/100
# 23/23 [==============================] - 9s 407ms/step - loss: 3.9307e-04 - val_loss: 4.4189e-04
# Epoch 55/100
# 23/23 [==============================] - 4s 191ms/step - loss: 4.1374e-04 - val_loss: 5.0509e-04
# Epoch 56/100
# 23/23 [==============================] - 4s 179ms/step - loss: 3.8669e-04 - val_loss: 4.1708e-04
# Epoch 57/100
# 23/23 [==============================] - 8s 355ms/step - loss: 4.6329e-04 - val_loss: 4.2875e-04
# Epoch 58/100
# 23/23 [==============================] - 9s 382ms/step - loss: 5.0748e-04 - val_loss: 5.4005e-04
# Epoch 59/100
# 23/23 [==============================] - 10s 450ms/step - loss: 4.0603e-04 - val_loss: 5.2741e-04
# Epoch 60/100
# 23/23 [==============================] - 9s 412ms/step - loss: 3.8081e-04 - val_loss: 4.4805e-04
# Epoch 61/100
# 23/23 [==============================] - 10s 427ms/step - loss: 3.7544e-04 - val_loss: 3.7329e-04
# Epoch 62/100
# 23/23 [==============================] - 10s 444ms/step - loss: 3.5048e-04 - val_loss: 3.3551e-04
# Epoch 63/100
# 23/23 [==============================] - 11s 481ms/step - loss: 3.4189e-04 - val_loss: 3.3673e-04
# Epoch 64/100
# 23/23 [==============================] - 5s 205ms/step - loss: 3.5761e-04 - val_loss: 3.1585e-04
# Epoch 65/100
# 23/23 [==============================] - 3s 147ms/step - loss: 3.2983e-04 - val_loss: 3.6935e-04
# Epoch 66/100
# 23/23 [==============================] - 4s 163ms/step - loss: 3.2056e-04 - val_loss: 3.7459e-04
# Epoch 67/100
# 23/23 [==============================] - 4s 159ms/step - loss: 3.2526e-04 - val_loss: 3.3510e-04
# Epoch 68/100
# 23/23 [==============================] - 4s 159ms/step - loss: 3.0093e-04 - val_loss: 3.3325e-04
# Epoch 69/100
# 23/23 [==============================] - 4s 154ms/step - loss: 3.9547e-04 - val_loss: 2.7412e-04
# Epoch 70/100
# 23/23 [==============================] - 4s 161ms/step - loss: 3.5334e-04 - val_loss: 3.2765e-04
# Epoch 71/100
# 23/23 [==============================] - 4s 153ms/step - loss: 2.9797e-04 - val_loss: 3.6456e-04
# Epoch 72/100
# 23/23 [==============================] - 4s 161ms/step - loss: 2.8988e-04 - val_loss: 2.7805e-04
# Epoch 73/100
# 23/23 [==============================] - 4s 166ms/step - loss: 2.7893e-04 - val_loss: 3.4393e-04
# Epoch 74/100
# 23/23 [==============================] - 4s 177ms/step - loss: 2.8912e-04 - val_loss: 2.4993e-04
# Epoch 75/100
# 23/23 [==============================] - 4s 170ms/step - loss: 4.0914e-04 - val_loss: 3.0608e-04
# Epoch 76/100
# 23/23 [==============================] - 4s 171ms/step - loss: 2.7962e-04 - val_loss: 2.4912e-04
# Epoch 77/100
# 23/23 [==============================] - 4s 177ms/step - loss: 2.6755e-04 - val_loss: 2.5400e-04
# Epoch 78/100
# 23/23 [==============================] - 4s 171ms/step - loss: 2.8370e-04 - val_loss: 2.6807e-04
# Epoch 79/100
# 23/23 [==============================] - 4s 177ms/step - loss: 2.6457e-04 - val_loss: 2.6371e-04
# Epoch 80/100
# 23/23 [==============================] - 4s 194ms/step - loss: 2.5586e-04 - val_loss: 2.6054e-04
# Epoch 81/100
# 23/23 [==============================] - 4s 192ms/step - loss: 2.5429e-04 - val_loss: 4.0265e-04
# Epoch 82/100
# 23/23 [==============================] - 5s 198ms/step - loss: 2.5918e-04 - val_loss: 2.3354e-04
# Epoch 83/100
# 23/23 [==============================] - 5s 207ms/step - loss: 2.8709e-04 - val_loss: 2.3717e-04
# Epoch 84/100
# 23/23 [==============================] - 5s 203ms/step - loss: 2.4753e-04 - val_loss: 2.9950e-04
# Epoch 85/100
# 23/23 [==============================] - 4s 188ms/step - loss: 2.5147e-04 - val_loss: 3.1975e-04
# Epoch 86/100
# 23/23 [==============================] - 4s 191ms/step - loss: 2.4397e-04 - val_loss: 2.3522e-04
# Epoch 87/100
# 23/23 [==============================] - 4s 187ms/step - loss: 2.6851e-04 - val_loss: 2.3558e-04
# Epoch 88/100
# 23/23 [==============================] - 4s 171ms/step - loss: 3.0183e-04 - val_loss: 3.8190e-04
# Epoch 89/100
# 23/23 [==============================] - 4s 172ms/step - loss: 2.3886e-04 - val_loss: 3.2714e-04
# Epoch 90/100
# 23/23 [==============================] - 4s 183ms/step - loss: 2.6709e-04 - val_loss: 2.8725e-04
# Epoch 91/100
# 23/23 [==============================] - 4s 171ms/step - loss: 2.5344e-04 - val_loss: 2.3031e-04
# Epoch 92/100
# 23/23 [==============================] - 4s 176ms/step - loss: 2.7110e-04 - val_loss: 2.4549e-04
# Epoch 93/100
# 23/23 [==============================] - 4s 180ms/step - loss: 2.4063e-04 - val_loss: 3.1349e-04
# Epoch 94/100
# 23/23 [==============================] - 4s 172ms/step - loss: 2.3596e-04 - val_loss: 2.7962e-04
# Epoch 95/100
# 23/23 [==============================] - 4s 190ms/step - loss: 2.3577e-04 - val_loss: 2.5682e-04
# Epoch 96/100
# 23/23 [==============================] - 4s 170ms/step - loss: 2.4529e-04 - val_loss: 3.1409e-04
# Epoch 97/100
# 23/23 [==============================] - 4s 172ms/step - loss: 2.4860e-04 - val_loss: 2.0815e-04
# Epoch 98/100
# 23/23 [==============================] - 4s 172ms/step - loss: 2.3067e-04 - val_loss: 3.4471e-04
# Epoch 99/100
# 23/23 [==============================] - 4s 171ms/step - loss: 2.1798e-04 - val_loss: 2.6641e-04
# Epoch 100/100
# 23/23 [==============================] - 4s 173ms/step - loss: 2.0804e-04 - val_loss: 2.7188e-04

# %%
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)
# Out:
# 45/45 [==============================] - 3s 32ms/step
# 13/13 [==============================] - 0s 30ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
math.sqrt(mean_squared_error(y_train, train_predict))
# Out:
# 166.75947203712172

# %%
math.sqrt(mean_squared_error(y_test, test_predict))
# Out:
# 108.85261249936808

# %%
look_back = 100
trainPredictPlot = np.empty_like(high_df)
trainPredictPlot[:,:] = np.nan
trainPredictPlot[look_back:len(train_predict) + look_back, :] = train_predict

testPredictPlot = np.empty_like(high_df)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(train_predict) + (look_back * 2)+1:len(high_df) - 1, :] = test_predict

# %%
plt.plot(scaler.inverse_transform(high_df))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.legend(['Complete Data', 'Train Data', 'Predicted Data'])
plt.show()

# %%
len(test_data), x_test.shape
# Out:
# (509, (408, 100, 1))

# %%
x_input = test_data[409:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

first_output = []
n_steps = 100
nextNumberOfDays = 28
i = 0

while i < 100:
            x_input = np.array(temp_input[1:])
            print("{} day input {}".format(i, x_input))
            x_input = x_input.reshape(1, -1)

            yhat = model.predict(x_input, verbose=0)
            print("{} day output {}".format(i, yhat))

            temp_input.extend(yhat[0].tolist())
            temp_input = temp_input[1:]
            i += 1
x_input = x_input.reshape((1, n_steps, 1))
yhat = model.predict(x_input, verbose=0)
first_output.extend(yhat.tolist())
i += 1

print(yhat[0])
temp_input.extend(yhat[0].tolist())

print(len(temp_input))
print(first_output)
# Out:
# 0 day input [0.13356373 0.13498679 0.14108559 0.13498679 0.12644847 0.12685505
#  0.12482212 0.14515145 0.1467778  0.15003049 0.15368977 0.17198618
#  0.16548079 0.17625534 0.17564546 0.19129904 0.20817239 0.20309006
#  0.18479366 0.17930474 0.1896727  0.17483228 0.17849156 0.17645863
#  0.18540354 0.18377719 0.19190892 0.18987599 0.19028258 0.19394186
#  0.20004066 0.19638138 0.19495832 0.20349665 0.19597479 0.21162838
#  0.22036999 0.20979874 0.21528766 0.21589754 0.21610083 0.22748526
#  0.19150234 0.1833706  0.17340923 0.16751372 0.1622281  0.17056312
#  0.17462899 0.17930474 0.18174426 0.16853019 0.16548079 0.1742224
#  0.1713763  0.17300264 0.17157959 0.17767839 0.18459036 0.18702988
#  0.18987599 0.19109575 0.18581012 0.17015654 0.16751372 0.16974995
#  0.16609067 0.15531612 0.15003049 0.15064037 0.14860744 0.14596463
#  0.15043708 0.14413499 0.12441553 0.12827811 0.11547062 0.12034966
#  0.13478349 0.13498679 0.12868469 0.13295385 0.12807481 0.12624517
#  0.13051433 0.13905265 0.14718439 0.15104696 0.14515145 0.14311852
#  0.15816223 0.15328319 0.14921732 0.15531612 0.15917869 0.15938199
#  0.16344786]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 14
#      11 print("{} day input {}".format(i, x_input))
#      12 x_input = x_input.reshape(1, -1)
# ---> 14 yhat = model.predict(x_input, verbose=0)
#      15 print("{} day output {}".format(i, yhat))
#      17 temp_input.extend(yhat[0].tolist())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filecs5ivuhm.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# TypeError: in user code:
#
#     File "C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\keras\engine\training.py", line 2169, in predict_function  *
#         return step_function(self, iterator)
#     File "C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\keras\engine\training.py", line 2155, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\keras\engine\training.py", line 2143, in run_step  **
#         outputs = model.predict_step(data)
#     File "C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\keras\engine\training.py", line 2111, in predict_step
#         return self(x, training=False)
#     File "C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\keras\layers\rnn\lstm.py", line 615, in call
#         timesteps = input_shape[0] if self.time_major else input_shape[1]
#
#     TypeError: Exception encountered when calling layer 'lstm' (type LSTM).
#
#     'NoneType' object is not subscriptable
#
#     Call arguments received by layer 'lstm' (type LSTM):
#       • inputs=tf.Tensor(shape=<unknown>, dtype=float32)
#       • mask=None
#       • training=False
#       • initial_state=None
